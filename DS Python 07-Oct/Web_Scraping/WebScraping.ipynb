# %%
html=['<html><heading style="font-size:20px"><i>This is the title<br><br></i></heading>',
     '<body><b>This is the body</b><p id="para1">This is para1<a href="www.google.com">Google</a></p>',
     '<p id="para2">This is para 2</p></body></html>']

# %%
html = "".join(html)

# %%
html
# Out:
# '<html><heading style="font-size:20px"><i>This is the title<br><br></i></heading><body><b>This is the body</b><p id="para1">This is para1<a href="www.google.com">Google</a></p><p id="para2">This is para 2</p></body></html>'

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html)

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <heading style="font-size:20px">
#    <i>
#     This is the title
#     <br/>
#     <br/>
#    </i>
#   </heading>
#   <b>
#    This is the body
#   </b>
#   <p id="para1">
#    This is para1
#    <a href="www.google.com">
#     Google
#    </a>
#   </p>
#   <p id="para2">
#    This is para 2
#   </p>
#  </body>
# </html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.html
# Out:
# <html><body><heading style="font-size:20px"><i>This is the title<br/><br/></i></heading><b>This is the body</b><p id="para1">This is para1<a href="www.google.com">Google</a></p><p id="para2">This is para 2</p></body></html>

# %%
soup.body
# Out:
# <body><heading style="font-size:20px"><i>This is the title<br/><br/></i></heading><b>This is the body</b><p id="para1">This is para1<a href="www.google.com">Google</a></p><p id="para2">This is para 2</p></body>

# %%
soup.p #1st p tag
# Out:
# <p id="para1">This is para1<a href="www.google.com">Google</a></p>

# %%
soup.b #1st b tag
# Out:
# <b>This is the body</b>

# %%
soup.b.text
# Out:
# 'This is the body'

# %%
a=soup.p
type(a)
# Out:
# bs4.element.Tag

# %%
a.text
# Out:
# 'This is para1Google'

# %%
soup.html.text
# Out:
# 'This is the titleThis is the bodyThis is para1GoogleThis is para 2'

# %%
soup.p
# Out:
# <p id="para1">This is para1<a href="www.google.com">Google</a></p>

# %%
soup.p.contents
# Out:
# ['This is para1', <a href="www.google.com">Google</a>]

# %%
soup.p.next_sibling
# Out:
# <p id="para2">This is para 2</p>

# %%
soup.p.parent
# Out:
# <body><heading style="font-size:20px"><i>This is the title<br/><br/></i></heading><b>This is the body</b><p id="para1">This is para1<a href="www.google.com">Google</a></p><p id="para2">This is para 2</p></body>

# %%
bd=soup.body
type(bd)
# Out:
# bs4.element.Tag

# %%
bd.heading
# Out:
# <heading style="font-size:20px"><i>This is the title<br/><br/></i></heading>

# %%
print(bd.prettify())
# Out:
# <body>
#  <heading style="font-size:20px">
#   <i>
#    This is the title
#    <br/>
#    <br/>
#   </i>
#  </heading>
#  <b>
#   This is the body
#  </b>
#  <p id="para1">
#   This is para1
#   <a href="www.google.com">
#    Google
#   </a>
#  </p>
#  <p id="para2">
#   This is para 2
#  </p>
# </body>

# %%
soup.p.parent
# Out:
# <body><heading style="font-size:20px"><i>This is the title<br/><br/></i></heading><b>This is the body</b><p id="para1">This is para1<a href="www.google.com">Google</a></p><p id="para2">This is para 2</p></body>

# %%
soup
# Out:
# <html><body><heading style="font-size:20px"><i>This is the title<br/><br/></i></heading><b>This is the body</b><p id="para1">This is para1<a href="www.google.com">Google</a></p><p id="para2">This is para 2</p></body></html>

# %%
soup.find('p') #to find the first p tag
# Out:
# <p id="para1">This is para1<a href="www.google.com">Google</a></p>

# %%
soup.find_all('p') #to find all the p tags
# Out:
# [<p id="para1">This is para1<a href="www.google.com">Google</a></p>,
#  <p id="para2">This is para 2</p>]

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <heading style="font-size:20px">
#    <i>
#     This is the title
#     <br/>
#     <br/>
#    </i>
#   </heading>
#   <b>
#    This is the body
#   </b>
#   <p id="para1">
#    This is para1
#    <a href="www.google.com">
#     Google
#    </a>
#   </p>
#   <p id="para2">
#    This is para 2
#   </p>
#  </body>
# </html>

# %%
#to find all the links
[x] = soup.find_all("a")

# %%
x
# Out:
# <a href="www.google.com">Google</a>

# %%
x["href"]
# Out:
# 'www.google.com'

# %%
x.get("href")
# Out:
# 'www.google.com'

# %%
x.text
# Out:
# 'Google'

# %% [markdown]
# ------

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html_doc)

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
#to find all the links
lst = soup.find_all("a")
lst
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
lst[0]["href"]
# Out:
# 'http://example.com/elsie'

# %%
lst[0].get("href")
# Out:
# 'http://example.com/elsie'

# %%
l = []
for row in lst:
    l.append(row.get("href"))

# %%
l
# Out:
# ['http://example.com/elsie',
#  'http://example.com/lacie',
#  'http://example.com/tillie']

# %%
l = soup.find_all("p", {"class": "story"})
l
# Out:
# [<p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>, <p class="story">...</p>]

# %%
len(l)
# Out:
# 2

# %%
import re
soup.find_all('a', {"href": re.compile("http://\w")})
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
import re
soup.find_all('a', {"href": re.compile("http://\w")})
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# ----

# %%
import requests
url = "https://www.simplilearn.com/"

# %%
r = requests.get(url)

# %%
#r.text

# %%
soup = BeautifulSoup(r.text)

# %%
l = []
for tag in soup.find_all("a"):
    l.append(tag.get("href"))

# %%
print(l)
# Out:
# ['https://www.simplilearn.com/resources', 'https://www.simplilearn.com/corporate-training', 'https://www.simplilearn.com/higher-education-partnership-program-for-universities', 'https://www.simplilearn.com', None, '', None, 'resources', 'reseller-partner-program-for-training-courses', 'gsa-advantage-training-courses-for-government-employees', 'corporate-training', 'digital-transformation-training', 'https://www.simplilearn.com/data-science-post-graduate-program-with-purdue-university?referrer=home', 'https://www.simplilearn.com/digital-marketing/advanced-online-marketing-certification-training-bundle?referrer=home', 'https://www.simplilearn.com/cloud-solutions-architect-masters-program-training?referrer=home', 'https://www.simplilearn.com/artificial-intelligence-masters-program-training-course?referrer=home', 'https://www.simplilearn.com/big-data-and-analytics/senior-data-scientist-masters-program-training?referrer=home', 'https://www.simplilearn.com/pmp-plus-bundle-masters-program?r
# ...

# %%
l = []
for tag in soup.find_all('a', {"href": re.compile("http\w")}):
    l.append(tag.get("href"))

# %%
l
# Out:
# ['https://www.simplilearn.com/resources',
#  'https://www.simplilearn.com/corporate-training',
#  'https://www.simplilearn.com/higher-education-partnership-program-for-universities',
#  'https://www.simplilearn.com',
#  'https://www.simplilearn.com/data-science-post-graduate-program-with-purdue-university?referrer=home',
#  'https://www.simplilearn.com/digital-marketing/advanced-online-marketing-certification-training-bundle?referrer=home',
#  'https://www.simplilearn.com/cloud-solutions-architect-masters-program-training?referrer=home',
#  'https://www.simplilearn.com/artificial-intelligence-masters-program-training-course?referrer=home',
#  'https://www.simplilearn.com/big-data-and-analytics/senior-data-scientist-masters-program-training?referrer=home',
#  'https://www.simplilearn.com/pmp-plus-bundle-masters-program?referrer=home',
#  'https://www.simplilearn.com/quality-management/lean-six-sigma-certification-training-all-in-one-bundle?referrer=home',
# ...

# %% [markdown]
# ----

# %%
! pip unistall requests

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.amazon.in/Echo-Dot-3rd-Gen-improved/product-reviews/B07PFFMP9P/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=1"

# %%
r = requests.get(url)

# %%
r.text
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'><link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com"><link rel="dns-prefetch" href="https://m.media-amazon.com"><link rel="dns-prefetch" href="https://completion.amazon.com"><!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/51tax7M48-L._RC|516fcOUE-HL.css,01evdoiemkL.css,01K+Ps1DeEL.css,31pdJv9iSzL.css,01VszOUTO6L.css,11UGC+GXOPL.css,21LK7jaicML.css,11L58Qpo0GL.css,21kyTi1FabL.css,01ruG+gDPFL.css,01YhS3Cs-hL.css,21GwE3cR-yL.css,019SHZnt8RL.css,01wAWQRgXzL.css,21bWcRJYNIL.css,11WgRxUdJRL.css,01dU8+SPlFL.css,11ocrgKoE-L.css,01SHjPML6tL.css,111-D2qRjiL.css,01QrWuRrZ-L.css,310Imb6LqFL.css,11Z1a0FxSIL.css,01cbS3UK11L.css,21mOLw+
# ...

# %%
soup=BeautifulSoup(r.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:feature:aui-assets -->
# ...

# %%
lst = []
for p in soup.find_all("a", {"class":"a-link-normal"}):
    lst.append(p.get("title"))

# %%
len(lst)
# Out:
# 122

# %%
m = soup.find_all("span",{"class":"a-icon-alt"})

# %%
m
# Out:
# [<span class="a-icon-alt">4.3 out of 5 stars</span>,
#  <span class="a-icon-alt">5.0 out of 5 stars</span>,
#  <span class="a-icon-alt">3.0 out of 5 stars</span>,
#  <span class="a-icon-alt">3.0 out of 5 stars</span>,
#  <span class="a-icon-alt">1.0 out of 5 stars</span>,
#  <span class="a-icon-alt">5.0 out of 5 stars</span>,
#  <span class="a-icon-alt">4.0 out of 5 stars</span>,
#  <span class="a-icon-alt">5.0 out of 5 stars</span>,
#  <span class="a-icon-alt">5.0 out of 5 stars</span>,
#  <span class="a-icon-alt">1.0 out of 5 stars</span>,
#  <span class="a-icon-alt">5.0 out of 5 stars</span>,
#  <span class="a-icon-alt">4.0 out of 5 stars</span>,
#  <span class="a-icon-alt">2.0 out of 5 stars</span>,
#  <span class="a-icon-alt">4.3 out of 5 stars</span>,
#  <span class="a-icon-alt">4.3 out of 5 stars</span>,
#  <span class="a-icon-alt">3.6 out of 5 stars</span>,
#  <span class="a-icon-alt">4.3 out of 5 stars</span>,
#  <span class="a-icon-alt">4.6 out of 5 stars</span>]

# %%
star = []
for sp in m:
    star.append(sp.text[:3])

# %%
len(star)
# Out:
# 18

# %% [markdown]
# -----

# %%
f = soup.find("div", {"id":"cm_cr-review_list", "class":"a-section a-spacing-none review-views celwidget"})

# %%
type(f)
# Out:
# bs4.element.Tag

# %%
m = f.find_all("span",{"class":"a-icon-alt"})

# %%
len(m)
# Out:
# 10

# %%
f.find_all("span", {"data-hook":"review-body", "class":"a-size-base review-text review-text-content"})
# Out:
# [<span class="a-size-base review-text review-text-content" data-hook="review-body"><span class="">This is very good hardware and speaker. However very much handicapped by amazon on software front. It can not understand your commands 70-80 percentage times and very limited to amazon music and saavn. However you can not use any of good music apps like wynk, gaana, youtube etc.<br/>Also natural language processing is supported in google products but not in this echo.<br/>For example when you say-<br/>1) where is agra - it gives you correct answer.<br/>2) continue with next query like how to reach there ?<br/>Then for 2nd query it doesn't know what to do..<br/>This is just an example but most of the times you will find this issue there.<br/><br/>Then you can not connect with other populer music etc apps. Have to rely on what amazon thinks os good for you.<br/>Amazon music has very limited music base.<br/><br/>So looking forward to get more access and integration with alexa however not ha
# ...
