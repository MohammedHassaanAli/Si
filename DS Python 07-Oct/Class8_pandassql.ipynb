# %%
import pandas as pd
import pandasql as pdsql

# %%
t = pd.read_csv(r"C:\Users\Vaibhav\Desktop\BA\Datasets\titanic_train.csv")

# %%
t[:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
str1 = "select Name, Age, Pclass from t where Age>35 or SibSp<1"

# %%
var= pdsql.sqldf(str1)

# %%
var
# Out:
#                                                   Name   Age  Pclass
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1
# 1                               Heikkinen, Miss. Laina  26.0       3
# 2                             Allen, Mr. William Henry  35.0       3
# 3                                     Moran, Mr. James   NaN       3
# 4                              McCarthy, Mr. Timothy J  54.0       1
# 5    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0       3
# 6                             Bonnell, Miss. Elizabeth  58.0       1
# 7                       Saundercock, Mr. William Henry  20.0       3
# 8                          Andersson, Mr. Anders Johan  39.0       3
# 9                 Vestrom, Miss. Hulda Amanda Adolfina  14.0       3
# 10                    Hewlett, Mrs. (Mary D Kingcome)   55.0       2
# 11                        Williams, Mr. Charles Eugene   NaN       2
# 12                             Masselmani, Mrs. Fatima   NaN       3
# ...
