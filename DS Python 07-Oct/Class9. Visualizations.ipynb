# %% [markdown]
# # Data Visualizations
# - univariate visualizations for a continuous var: histogram, kde, boxplot, violinplot, lineplot(to show how the variance in the data)
# - univariate visualizations for a factor var: barplot, pie chart
# - bivariate - continuous: scatterplot. kde
# - bivariate - factor+continuous: find the mean age according to pclass and plot using barplots
#     - you can seperate out the distribution of age according to each level and do a univariate analysis on each of the distributions for comparison purpose
# - bivariate - factor + factor: factorplots, sns barplots -%age of survived based on gender
# - multivariate: cont+cont+factor: scatter plots and hue according to the factor var
# - multivariate: factor+factor+cont: violin plots according to the level in factor variable1 and split color according to factor var2; 2nd we did barplots after grouping according to 2 factor variables find out the mean age and create bar plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#%matplotlib inline - display the plots inline within the jupyter notebook

# %%
print(plt.style.available)
# Out:
# ['fivethirtyeight', '_classic_test', 'fast', 'bmh', 'tableau-colorblind10', 'seaborn-muted', 'seaborn-ticks', 'seaborn-notebook', 'Solarize_Light2', 'seaborn-whitegrid', 'dark_background', 'seaborn-darkgrid', 'ggplot', 'seaborn-paper', 'seaborn-dark-palette', 'grayscale', 'seaborn-pastel', 'seaborn-white', 'seaborn-deep', 'seaborn-dark', 'seaborn-colorblind', 'seaborn-talk', 'seaborn-poster', 'seaborn-bright', 'seaborn', 'classic']

# %%
plt.style.use("seaborn-whitegrid")

# %%
sns.set(palette="muted", style="dark")
#style: darkgrid, whitegrid, dark, white and ticks
#palette: deep, muted, pastel, bright, dark, colorblind or you can create custom palette
#this can change the style for all the visualizations (matplotlib or sns visualizations)
#the color palette will be applicable through this command only on sns visualizations

# %%
print(plt.colormaps())
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r
# ...

# %% [markdown]
# - plt.figure(figsize = (10,4)) #length X width
# - plt.set_size_inches(10,4)
# - plt.style.use("ggplot")
# - plt.title("Title")
# - plt.xlabel("X Label")
# - plt.ylabel("Y Label")
# - plt.xticks(ticks = np.arange(5), labels = ('Tom', 'Dick', 'Harry', 'Sally', 'Sue'), rotation=20)
# - plt.xticks(np.arange(0, 1, step=0.2))
# - plt.yticks(<same as xticks>)
# - plt.legend()
# - plt.xlim(0,50)
# - plt.ylim(0,40)
# - plt.axis([xmin, xmax, ymin, ymax])
# - plt.savefig("violinplot.png")
# - plt.show() #will ignore the text and display only the image

# %% [markdown]
# ### Line Plots

# %%
np.random.seed(1) #to replicate the same random numbers multiple times
ran = np.random.rand(100)
ran[:10]
# Out:
# array([4.17022005e-01, 7.20324493e-01, 1.14374817e-04, 3.02332573e-01,
#        1.46755891e-01, 9.23385948e-02, 1.86260211e-01, 3.45560727e-01,
#        3.96767474e-01, 5.38816734e-01])

# %%
plt.figure(figsize = (10,4))
plt.plot(ran, color = '#76448A', ls = "-.", label = "line1", marker = "o", linewidth = 2, alpha = .6)
#alpha - transparency level - alpha = 1 means 100% opaque line
#color - any hexadecimal code or abbreviations: 'r', 'b', 'g'
#marker - + . 1234 o
#linestyle - ls = (-, --, -., steps)
plt.show()

# %%
monday = [12,10, 20, 32]
tuesday = [20,39,18, 23]
wednesday=[ 14,34, 23, 27]
time_hrs = [1,2,3,4]

# %%
plt.figure(figsize = (10,3))
plt.plot(time_hrs,monday, 'r', label = "monday", linewidth = 2)#label important for legend
plt.plot(time_hrs,tuesday, 'g', label = "tuesday", linewidth = 1)
plt.plot(time_hrs,wednesday, 'b', label = "wednesday", linewidth = 3)
plt.legend(loc = "best")
plt.title("Website Traffic")
plt.show()

# %%
bosdf = pd.read_csv("boston.csv")
bosdf.head(3)
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7

# %%
#line plots used to analyse the covariance - covariance means how the variable is 
#varying wrt other variables 
plt.figure(figsize = (10,3))
plt.plot(bosdf["MEDV"],label = "MEDV")#row number in x axis and y = Median value
plt.plot(bosdf['CRIM'], label = "CRIM")#row number in x and y axis - crime rate
plt.plot(bosdf['AGE'], label = "Age")#row number in x axis and y axis has age
plt.legend()
plt.show()

# %%
bosdf.index
# Out:
# RangeIndex(start=0, stop=506, step=1)

# %%
#subplots - diff plots side by side

# %%
plt.figure(figsize=(10,4))
plt.subplots_adjust(left = .2, wspace = .1, hspace = .8)

plt.subplot(2,2,1) #1 row 2 columns, 1st subplot
plt.plot(monday, "-o", alpha = .9, color = 'r')
plt.title("Monday".upper())
plt.xlabel("Monday")


plt.subplot(2,2,2) #2nd subplot
plt.plot(tuesday, "-", color = "b")
plt.title("Tuesday".upper())

plt.subplot(2,2,3) #2nd subplot
plt.plot(wednesday, "-", color = "b")
plt.title("Wednesday".upper())

plt.subplot(2,2,4) #1 row 2 columns, 1st subplot
plt.plot(monday, "-o", alpha = 1, color = 'r')
plt.title("Monday".upper())



plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### UNIVARIATE ANALYSIS OF A FACTOR VARIABLE

# %%
tab = bosdf.CHAS.value_counts()
tab
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
bosdf.plot()

# %%
#?bosdf.plot

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }

# %%
bosdf["CHAS"].value_counts().plot.bar()

# %%
pd.value_counts(bosdf.CHAS).plot(kind= "bar", colormap = "RdBu" , title = "Chas", figsize = (10,4))
plt.title("chas". upper(), font)
plt.xlabel("Chas", fontdict = font)
plt.ylabel("Frequency", font)
plt.show()

# %%
tab = pd.value_counts(bosdf["CHAS"])
tab
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
tab.index = ["0", "1"]
tab.index
# Out:
# Index(['0', '1'], dtype='object')

# %%
plt.bar(x = tab.index, height = tab, color = "yellow", edgecolor = "k", linewidth = 2, alpha = .5) #k represents black col
# Out:
# <BarContainer object of 2 artists>

# %%
bosdf.plot()

# %%
plt.figure(figsize=(10,3))
pd.value_counts(bosdf.CHAS).plot(kind = "bar", colormap = "Accent")
plt.show()

# %%
sns.color_palette()
# Out:
# [(0.2823529411764706, 0.47058823529411764, 0.8156862745098039),
#  (0.9333333333333333, 0.5215686274509804, 0.2901960784313726),
#  (0.41568627450980394, 0.8, 0.39215686274509803),
#  (0.8392156862745098, 0.37254901960784315, 0.37254901960784315),
#  (0.5843137254901961, 0.4235294117647059, 0.7058823529411765),
#  (0.5490196078431373, 0.3803921568627451, 0.23529411764705882),
#  (0.8627450980392157, 0.49411764705882355, 0.7529411764705882),
#  (0.4745098039215686, 0.4745098039215686, 0.4745098039215686),
#  (0.8352941176470589, 0.7333333333333333, 0.403921568627451),
#  (0.5098039215686274, 0.7764705882352941, 0.8862745098039215)]

# %%
pal = ['#CD5C5C', "#E9967A", "#F08080"] #you can give your custom palette in sns plots

# %%
sns.set(style = "whitegrid", palette="bright")
#style: darkgrid, whitegrid, dark, white and ticks
#palette: deep, muted, pastel, bright, dark, colorblind or you can create custom palette

# %%
sns.countplot(x = bosdf["CHAS"], palette=pal) #x = bosdf["CHAS"] or x = "CHAS", data = bosdf
plt.xlabel("CHAS".capitalize(), fontdict=font)
plt.ylabel("frequency".capitalize(), font)
plt.show()

# %%
sns.countplot(x= 'CHAS', data=bosdf)
plt.title("CHAS", font)
plt.show()

# %%
tab
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.pie(tab, labels=tab.index,explode = (.05,.05), startangle=70, autopct = '%1.2f%%', )
plt.show()

#%1.1f%% - for 1 decimal place
#%1.2f%% - for 2 decimal places

# %% [markdown]
# ### Univariate Analysis of continuous variables

# %%
bosdf['MEDV'].plot.hist(bins = 50, colormap = "Accent")
plt.axis([0,50,0,40])
plt.show()

# %%
sns.set(palette="deep", style="ticks")
#style: darkgrid, whitegrid, dark, white and ticks
#palette: deep, muted, pastel, bright, dark, colorblind or you can create custom palette

# %%
plt.hist(bosdf.MEDV, bins = 50, color = "red",density = False ) #hist does not have cmap argument, but other plt commands have
plt.show()

# %%
bosdf["MEDV"].plot(kind = "kde")

# %%
sns.distplot(a = bosdf.MEDV, bins = 10, kde = True)

# %%
sns.boxplot(data = bosdf, palette=pal)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.boxplot(bosdf['MEDV'])
plt.show()

# %%
#IQR = Q3-Q1
#any value smaller than Q1-1.5IQR is a bottom outlier
#any value greater than Q3+1.5IQR is a top outlier

# %%
sns.boxplot(data= bosdf[['AGE', 'MEDV']])

# %%
sns.violinplot(bosdf['CRIM'])
#this tells about the dist + boxplot
#bi-modal multi-modal uni-modal

# %%
sns.kdeplot(bosdf.AGE)

# %% [markdown]
# ### BIVARIATE ANALYSIS - FACTOR + CONTINUOUS VARIABLES

# %%
from sklearn import datasets
d = datasets.load_boston()

# %%
d.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
bosdf.groupby("CHAS").MEDV.mean()
# Out:
# CHAS
# 0    22.093843
# 1    28.440000
# Name: MEDV, dtype: float64

# %%
plt.figure(figsize=(6,3))
bosdf.groupby("CHAS").MEDV.mean().plot(kind = "bar")
plt.show()

# %%
#we can create univariate visualizations for medv var with chas = 0 
#we can create univariate visualizations for medv var with chas = 1
MEDV_with_CHAS0 = bosdf.MEDV[bosdf.CHAS==0]
MEDV_with_CHAS1 = bosdf.MEDV[bosdf.CHAS==1]

# %%
sns.violinplot(x = "CHAS", y = "MEDV", data = bosdf)

# %%
#another way of creating subplots
f,ax = plt.subplots(2,2, figsize = (18,10)) #f is the figure and ax is the axis
plt.subplots_adjust(left = .2, wspace = .1, hspace = .8)

bosdf[bosdf.CHAS == 0].MEDV.plot.hist(ax = ax[0,0], bins = 10, color = "red")
ax[0,0].set_title("CHAS = 0", font)
ax[0,0].set_xticks(range(5,50,3))
ax[0,0].set_xlabel("MEDV", font)

bosdf[bosdf.CHAS ==1].MEDV.plot.hist(ax = ax[0,1], color = "b")
ax[0,1].set_title("CHAS=1")
ax[0,1].set_xticks(range(10,50, 2))
ax[0,1].set_xlabel("MEDV")

bosdf[bosdf.CHAS == 0].MEDV.plot.kde(ax = ax[1,0], color = "red")
ax[1,0].set_title("CHAS = 0")
ax[1,0].set_xticks(range(5,50,3))
ax[1,0].set_xlabel("MEDV")


bosdf[bosdf.CHAS == 1].MEDV.plot.kde(ax = ax[1,1], color = "red")
ax[1,1].set_title("CHAS = 0")
ax[1,1].set_xticks(range(5,50,3))
ax[1,1].set_xlabel("MEDV")

plt.savefig("abc.jpeg")

# %% [markdown]
# ### 2 continuous variables

# %%
plt.scatter(bosdf.AGE, bosdf.MEDV, s = 50, cmap = 'RdYlGn')

# %%
bosdf.plot.scatter(x = "AGE", y = "MEDV",  )
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.lmplot(x = "AGE", y = "MEDV", data = bosdf, fit_reg=False, hue = "CHAS") #hue argument in seaborn helps us vary the hue according to a factor variable 
#very useful for multi-variate analysis

# %%
sns.lmplot(x = "AGE", y = "MEDV", data = bosdf, fit_reg = True)

# %%
sns.lmplot(x = "AGE", y = "MEDV", data = bosdf, fit_reg =True, hue = "CHAS", palette = "deep" )

# %%
sns.kdeplot(bosdf.AGE, bosdf.MEDV)

# %%
sns.jointplot(x = bosdf["AGE"], y = bosdf["MEDV"], kind = "scatter")

# %%
corr = bosdf.corr()
corr
# Out:
#              CRIM        ZN     INDUS      CHAS        NX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NX       0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
#to represent correlations - heatmap
plt.figure(figsize=(10,4))
corr = bosdf.corr()
sns.heatmap(corr,annot= True,cmap = "Dark2_r")

# %% [markdown]
# ### FACTOR + FACTOR

# %%
df = pd.read_csv(r"titanic_train.csv")

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
pd.crosstab(index = df.Sex, columns=df.Survived, margins = True)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %%
pd.crosstab(index = df.Sex, columns = df.Survived ).plot(kind = "bar", stacked = True, figsize = (5,3))

# %%
pd.crosstab(index = df.Sex, columns = df.Survived )
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
df.Survived.mean()
# Out:
# 0.3838383838383838

# %%
#%age of people who survived 
#equal to total number of 1s out of total number of passengers

# %%
tab = df.groupby("Sex").Survived.mean()
tab
#gives us the percentage of males and females who survived
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby(['Sex'])['Survived'].mean().plot.barh()

# %%
plt.bar(x = tab.index, height = tab)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.figure(figsize = (8,3))
sns.countplot('Sex', hue = 'Survived', data = df)

# %%
import warnings
warnings.filterwarnings(action = "ignore")
plt.figure(figsize=(5,3))
sns.factorplot('Sex', 'Survived', data = df)
plt.show()
#gives the %age of survived as per the gender
#also gives the 95% confidence interval of the survival rate
#with a 95% confidence we can say that the survival rate of males varies between .1 and .225
#with a 95% confidence we can say that the survival rate of females varies between .7 and .77

# %%
plt.figure(figsize=(5,3))
sns.barplot("Sex", "Survived", data = df, ci = 99 )
#survival rate + 95% confidence interval

# %% [markdown]
# ### factor + factor + continuous

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.groupby(["Survived", "Pclass"]).Age.mean().unstack()
# Out:
# Pclass            1          2          3
# Survived
# 0         43.695312  33.544444  26.555556
# 1         35.368197  25.901566  20.646118

# %%
df.groupby(["Survived", "Pclass"]).Age.mean().unstack().plot.bar(figsize = (5,3))

# %%
#continuous+ factor+factor

# %%
sns.violinplot("Pclass", "Age", data = df, hue = "Sex", split = True)
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.lmplot(x ="Age", y = "Fare", data = df,hue= "Survived", fit_reg=False)

# %%
#Factor + Factor + Factor + Factor

# %%
sns.factorplot("Pclass", "Survived",data = df, hue = "Sex")
# Out:
# C:\Users\Vaibhav\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
plt.figure(figsize=(20, 10))
sns.factorplot("Pclass", "Survived", data = df, hue = "Sex", col = "Embarked")
# Out:
# C:\Users\Vaibhav\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
pd.crosstab(df.Sex, df.Pclass)
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
plt.figure(figsize=(20,10))
sns.pairplot(data = bosdf.iloc[:,4:7], kind = "scatter")#plots the pairs of variables to understand the inter-correlations between the variables
#gives the univariate analysis in terms of histograms and bivariate in terms of scatter plots

# %%
#for a linear causation relationship to exist between a y variable and the x variable, there has to be high correlation between them
# y = mx+c -indicates that there is a high correlation (either +ve or -ve between x and y vars)
#there should not be any inter-correlations between the x variables to avoid multi-collinearity

# %%
#y variable is factor variable like titanic case 
#survived can be converted to survival rate

# %%
df.Survived.mean() #prob of survived
# Out:
# 0.3838383838383838

# %%
#y var vs x variables
df.groupby("Sex").Survived.mean().plot(kind = "bar") #is it creating a great variance in survival rate due to gender

# %%
df.groupby("Pclass").Survived.mean().plot(kind = "bar")

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.groupby("Survived").Fare.mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ### Visual analysis of titanic dataset

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
#print(list(df.Name))

# %%
print(list(df.Cabin))
# Out:
# [nan, 'C85', nan, 'C123', nan, nan, 'E46', nan, nan, nan, 'G6', 'C103', nan, nan, nan, nan, nan, nan, nan, nan, nan, 'D56', nan, 'A6', nan, nan, nan, 'C23 C25 C27', nan, nan, nan, 'B78', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'D33', nan, 'B30', 'C52', nan, nan, nan, nan, nan, 'B28', 'C83', nan, nan, nan, 'F33', nan, nan, nan, nan, nan, nan, nan, nan, 'F G73', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'C23 C25 C27', nan, nan, nan, 'E31', nan, nan, nan, 'A5', 'D10 D12', nan, nan, nan, nan, 'D26', nan, nan, nan, nan, nan, nan, nan, 'C110', nan, nan, nan, nan, nan, nan, nan, 'B58 B60', nan, nan, nan, nan, 'E101', 'D26', nan, nan, nan, 'F E69', nan, nan, nan, nan, nan, nan, nan, 'D47', 'C123', nan, 'B86', nan, nan, nan, nan, nan, nan, nan, nan, 'F2', nan, nan, 'C2', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'E33', nan, nan, nan, 'B19', nan, nan, nan, 'A7', nan, nan, 'C49', nan, nan, 
# ...

# %%
#All the univariate visualizations (for continuous you need to evaluate whether normal distribution or right skewed or left skewed).
#Right skewed distributions and left skewed distributions need to be converted to normal shape by taking log.
#There are more ways to handle this - converting into factor column i.e discretezing our cont var
#if there are only a few outliers, then those rows can be deleted.

#Univariate visualizations of factor variables will indicate if there sufficient sample for each level. 
#A balanced factor column is the best.

# %%
#Bivariate visualizations: with survived variable - with all the X columns to 
#understand whether they are leading to variance in survival status or not.

# %%
df.groupby("Sex").Survived.mean().plot.bar()
plt.show()

# %%
df.groupby("Pclass").Survived.mean().plot.barh()

# %%
df.groupby("Embarked").Survived.mean().plot.bar()

# %%
df.groupby(["Sex", "Pclass"]).Survived.mean().unstack()
#clearly shows further analysis is required
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
df.groupby(["Sex", "Pclass"]).Survived.mean().unstack().plot.bar()

# %%
df.groupby(["Sex", "Pclass"]).Survived.count().unstack().plot.bar()

# %%
#Notice that the frequency of males in Pclass 1 and 2 is same, but the survival rate of males in 
#Pclass 1 and 2 is varying hugely. This is not true for females, where also the frequency is same 
#but survival rate not varying hugely. 
#So Pclass * Gender is looking like a significant var which is  leading to variance in survival rate

# %%
pd.value_counts(df.Sex).plot.bar()

# %%
df.groupby(["Pclass", "Sex"]).Survived.mean().unstack().plot.bar()

# %%
df.groupby("Survived").Age.mean().plot.bar()

# %%
#mean age is not varying according to survived

# %%
df.groupby("Survived").Fare.mean().plot.bar()
